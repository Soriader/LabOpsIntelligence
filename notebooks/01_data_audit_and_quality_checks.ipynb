# %%
import pandas as pd
import numpy as np
import DataInspector as di

# ========================================================================================================================
# Load raw data
# ========================================================================================================================

df_lab_events = pd.read_csv('../data/raw/lab_events.csv', encoding='utf-8')
df_samples = pd.read_csv('../data/raw/samples.csv', encoding='utf-8')
df_tests = pd.read_csv('../data/raw/tests.csv', encoding='utf-8')

# ========================================================================================================================
# Number of rows and columns, unique values in priority and sample_id in samples
# ========================================================================================================================
di.DataInspector.display_dimensions(df_samples, "df_samples")
di.DataInspector.display_unique_value(df_samples, "df_samples","priority")
di.DataInspector.display_unique_value(df_samples, "df_samples","sample_id")

# ========================================================================================================================
# Number of null value in priority and client_name
# ========================================================================================================================

di.DataInspector.display_null_value(df_samples, "df_samples", "client_name")
di.DataInspector.display_null_value(df_samples, "df_samples", "priority")

# ========================================================================================================================
# Number of rows and columns, null value in result_value and unit coherence in tests
# ========================================================================================================================

di.DataInspector.display_dimensions(df_tests, "df_tests")
di.DataInspector.display_unique_value(df_tests, "df_tests","result_value")
di.DataInspector.display_unique_value(df_tests, "df_tests","unit")

# ========================================================================================================================
# 4) Checking the correctness of the time in lab_events
# ========================================================================================================================
# Out:
# ważne
# ==================================================
# 📊 PRIORITY VALIDATION: df_samples
# 📍 Column: priority
# ==================================================
# 📈 Allowed values: normal, high, urgent
# 🔍 Found unique values: high, normal, urgent, nan, rush, low, NORMAL
#
# ❌ INCORRECT values found: nan, rush, low, NORMAL
# 📊 Count of incorrect records: 4
# ==================================================
# ==================================================
# 📊 df_samples
# ==================================================
# 📈 Rows: 900
# 📑 Columns: 6
# 💾 Size: 900 × 6
# ==================================================
# ==================================================
# 📊 UNIQUE VALUES ANALYSIS: df_samples
# 📍 Column: priority
# ==================================================
# 📈 Total unique values: 6 / 900 (0.67%)
#
# 🔍 Unique values (first 6):
#    1. high
#    2. normal
#    3. urgent
#    4. nan
#    5. rush
#    6. low
#    7. NORMAL
# ==================================================
# ==================================================
# 📊 UNIQUE VALUES ANALYSIS: df_samples
# 📍 Column: sample_id
# ==================================================
# 📈 Total unique values: 900 / 900 (100.00%)
#
# 🔍 Unique values (first 20):
#    1. SMP-00001
#    2. SMP-00002
#    3. SMP-00003
#    4. SMP-00004
#    5. SMP-00005
#    6. SMP-00006
#    7. SMP-00007
#    8. SMP-00008
#    9. SMP-00009
#    10. SMP-00010
#    11. SMP-00011
#    12. SMP-00012
#    13. SMP-00013
#    14. SMP-00014
#    15. SMP-00015
#    16. SMP-00016
#    17. SMP-00017
#    18. SMP-00018
#    19. SMP-00019
#    20. SMP-00020
#    ... and 880 more
# ==================================================
# ==================================================
# 📊 NULL ANALYSIS: df_samples
# ==================================================
# 📈 Nulls in 'client_name': 18 (2.00%)
# ==================================================
# ==================================================
# 📊 NULL ANALYSIS: df_samples
# ==================================================
# 📈 Nulls in 'priority': 3 (0.33%)
# ==================================================
# ==================================================
# 📊 df_tests
# ==================================================
# 📈 Rows: 3,867
# 📑 Columns: 8
# 💾 Size: 3,867 × 8
# ==================================================
# ==================================================
# 📊 UNIQUE VALUES ANALYSIS: df_tests
# 📍 Column: result_value
# ==================================================
# 📈 Total unique values: 3,494 / 3,867 (90.35%)
#
# 🔍 Unique values (first 20):
#    1. 77.68
#    2. 363.2
#    3. 861.68
#    4. 104.47
#    5. 14.84
#    6. 70.0
#    7. 531.84
#    8. 731.91
#    9. 102.81
#    10. 15.48
#    11. 46.49
#    12. 919.76
#    13. 45.5
#    14. 14.59
#    15. 28.33
#    16. 220.39
#    17. 732.25
#    18. 69.23
#    19. 410.62
#    20. 808.45
#    ... and 3474 more
# ==================================================
# ==================================================
# 📊 UNIQUE VALUES ANALYSIS: df_tests
# 📍 Column: unit
# ==================================================
# 📈 Total unique values: 7 / 3,867 (0.18%)
#
# 🔍 Unique values (first 7):
#    1. mg/kg
#    2. kg/m3
#    3. cSt
#    4. C
#    5. ppm
#    6. nan
#    7. mg/L
#    8. %
# ==================================================
