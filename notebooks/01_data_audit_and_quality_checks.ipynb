# %%
import pandas as pd
import numpy as np
import DataInspector as di

# ============================================================
# 1) Load raw data
# ============================================================

df_lab_events = pd.read_csv('../data/raw/lab_events.csv', encoding='utf-8')
df_samples = pd.read_csv('../data/raw/samples.csv', encoding='utf-8')
df_tests = pd.read_csv('../data/raw/tests.csv', encoding='utf-8')

# ============================================================
# 2) Number of rows and columns, null value  in samples
# ============================================================
di.DataInspector.display_dimensions(df_samples, "df_samples")
di.DataInspector.display_null_value(df_samples, "df_samples")

di.DataInspector.display_unique_value(df_tests, "df_tests", "result_value")
di.DataInspector.display_null_value(df_tests, "df_tests")
# Out:
# ==================================================
# 📊 df_samples
# ==================================================
# 📈 Rows: 900
# 📑 Columns: 6
# 💾 Size: 900 × 6
# ==================================================
# ==================================================
# 📊 NULL ANALYSIS: df_samples
# ==================================================
# 📈 Total nulls: 21
#
# 📑 Nulls per column:
#    • priority: 3
#    • client_name: 18
# ==================================================
# ==================================================
# 📊 UNIQUE VALUES ANALYSIS: df_tests
# 📍 Column: result_value
# ==================================================
# 📈 Total unique values: 3,494 / 3,867 (90.35%)
#
# 🔍 Unique values (first 20):
#    1. 77.68
#    2. 363.2
#    3. 861.68
#    4. 104.47
#    5. 14.84
#    6. 70.0
#    7. 531.84
#    8. 731.91
#    9. 102.81
#    10. 15.48
#    11. 46.49
#    12. 919.76
#    13. 45.5
#    14. 14.59
#    15. 28.33
#    16. 220.39
#    17. 732.25
#    18. 69.23
#    19. 410.62
#    20. 808.45
#    ... and 3474 more
# ==================================================
# ==================================================
# 📊 NULL ANALYSIS: df_tests
# ==================================================
# 📈 Total nulls: 141
#
# 📑 Nulls per column:
#    • result_value: 80
#    • unit: 35
#    • analyst: 26
# ==================================================
