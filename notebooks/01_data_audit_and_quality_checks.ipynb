# %%
import pandas as pd
import numpy as np
import DataInspector as di

# ========================================================================================================================
# Load raw data
# ========================================================================================================================

df_lab_events = pd.read_csv('../data/raw/lab_events.csv', encoding='utf-8')
df_samples = pd.read_csv('../data/raw/samples.csv', encoding='utf-8')
df_tests = pd.read_csv('../data/raw/tests.csv', encoding='utf-8')

# ========================================================================================================================
# Number of rows and columns, unique and correct values in sample_id, priority and client_name in samples
# ========================================================================================================================
di.DataInspector.display_dimensions(df_samples, "df_samples")
di.DataInspector.display_unique_value(df_samples, "df_samples","sample_id")
di.DataInspector.display_unique_value(df_samples, "df_samples","priority")
di.DataInspector.display_correct_value(df_samples, "df_samples","priority", ["normal", "high", "urgent"])
di.DataInspector.display_unique_value(df_samples, "df_samples","client_name")

# ========================================================================================================================
# Number of null value in priority and client_name in samples
# ========================================================================================================================
di.DataInspector.display_null_value(df_samples, "df_samples", "client_name")
di.DataInspector.display_null_value(df_samples, "df_samples", "priority")

# ========================================================================================================================
# Number of rows and columns, null value in result_value and unit coherence in tests
# ========================================================================================================================
di.DataInspector.display_dimensions(df_tests, "df_tests")
di.DataInspector.display_unique_value(df_tests, "df_tests","result_value")
di.DataInspector.display_unique_value(df_tests, "df_tests","unit")

# ========================================================================================================================
# Checking the null value in result_value, unit and analyst
# ========================================================================================================================
di.DataInspector.display_null_value(df_tests, "df_samples", "result_value")
di.DataInspector.display_null_value(df_tests, "df_samples", "unit")
di.DataInspector.display_null_value(df_tests, "df_samples", "analyst")

# ========================================================================================================================
# Checking unique and correct values status in tests
# ========================================================================================================================
UNIT_RULES = {
    "sulfur": "mg/kg",
    "water": "mg/kg",
    "density": "kg/m3",
    "viscosity": "cSt",
    "chloride": "mg/kg",
    "flash_point": "C",
}

di.DataInspector.display_correct_value(df_tests, "df_tests","status", ["OK", "ERROR", "RETEST"])
di.DataInspector.units_correctness(df_tests, "df_tests", "parameter", UNIT_RULES)

# ========================================================================================================================
# Checking the correctness of the time in lab_events
# ========================================================================================================================
# Out:
# ==================================================
# 📊 df_samples
# ==================================================
# 📈 Rows: 900
# 📑 Columns: 6
# 💾 Size: 900 × 6
# ==================================================
# ==================================================
# 📊 UNIQUE VALUES ANALYSIS: df_samples
# 📍 Column: sample_id
# ==================================================
# 📈 Total unique values: 900 / 900 (100.00%)
#
# 🔍 Unique values (first 20):
#    1. SMP-00001
#    2. SMP-00002
#    3. SMP-00003
#    4. SMP-00004
#    5. SMP-00005
#    6. SMP-00006
#    7. SMP-00007
#    8. SMP-00008
#    9. SMP-00009
#    10. SMP-00010
#    11. SMP-00011
#    12. SMP-00012
#    13. SMP-00013
#    14. SMP-00014
#    15. SMP-00015
#    16. SMP-00016
#    17. SMP-00017
#    18. SMP-00018
#    19. SMP-00019
#    20. SMP-00020
#    ... and 880 more
# ==================================================
# ==================================================
# 📊 UNIQUE VALUES ANALYSIS: df_samples
# 📍 Column: priority
# ==================================================
# 📈 Total unique values: 6 / 900 (0.67%)
#
# 🔍 Unique values (first 6):
#    1. high
#    2. normal
#    3. urgent
#    4. nan
#    5. rush
#    6. low
#    7. NORMAL
# ==================================================
# ==================================================
# 📊 PRIORITY VALIDATION: df_samples
# 📍 Column: priority
# ==================================================
# 📈 Allowed values: normal, high, urgent
# 🔍 Found unique values: high, normal, urgent, nan, rush, low, NORMAL
#
# ❌ INCORRECT values found: nan, rush, low, NORMAL
# 📊 Count of incorrect records: 4
# ==================================================
# ==================================================
# 📊 UNIQUE VALUES ANALYSIS: df_samples
# 📍 Column: client_name
# ==================================================
# 📈 Total unique values: 6 / 900 (0.67%)
#
# 🔍 Unique values (first 6):
#    1. NordFuel
#    2. Baltic Energy
#    3. FuelCore
#    4. Orlenex
#    5. nan
#    6. ChemTrans
#    7. PetroMax
# ==================================================
# ==================================================
# 📊 NULL ANALYSIS: df_samples
# ==================================================
# 📈 Nulls in 'client_name': 18 (2.00%)
# ==================================================
# ==================================================
# 📊 NULL ANALYSIS: df_samples
# ==================================================
# 📈 Nulls in 'priority': 3 (0.33%)
# ==================================================
# ==================================================
# 📊 df_tests
# ==================================================
# 📈 Rows: 3,867
# 📑 Columns: 8
# 💾 Size: 3,867 × 8
# ==================================================
# ==================================================
# 📊 UNIQUE VALUES ANALYSIS: df_tests
# 📍 Column: result_value
# ==================================================
# 📈 Total unique values: 3,494 / 3,867 (90.35%)
#
# 🔍 Unique values (first 20):
#    1. 77.68
#    2. 363.2
#    3. 861.68
#    4. 104.47
#    5. 14.84
#    6. 70.0
#    7. 531.84
#    8. 731.91
#    9. 102.81
#    10. 15.48
#    11. 46.49
#    12. 919.76
#    13. 45.5
#    14. 14.59
#    15. 28.33
#    16. 220.39
#    17. 732.25
#    18. 69.23
#    19. 410.62
#    20. 808.45
#    ... and 3474 more
# ==================================================
# ==================================================
# 📊 UNIQUE VALUES ANALYSIS: df_tests
# 📍 Column: unit
# ==================================================
# 📈 Total unique values: 7 / 3,867 (0.18%)
#
# 🔍 Unique values (first 7):
#    1. mg/kg
#    2. kg/m3
#    3. cSt
#    4. C
#    5. ppm
#    6. nan
#    7. mg/L
#    8. %
# ==================================================
# ==================================================
# 📊 NULL ANALYSIS: df_samples
# ==================================================
# 📈 Nulls in 'result_value': 80 (2.07%)
# ==================================================
# ==================================================
# 📊 NULL ANALYSIS: df_samples
# ==================================================
# 📈 Nulls in 'unit': 35 (0.91%)
# ==================================================
# ==================================================
# 📊 NULL ANALYSIS: df_samples
# ==================================================
# 📈 Nulls in 'analyst': 26 (0.67%)
# ==================================================
# ==================================================
# 📊 PRIORITY VALIDATION: df_tests
# 📍 Column: status
# ==================================================
# 📈 Allowed values: OK, ERROR, RETEST
# 🔍 Found unique values: ERROR, OK, RETEST
#
# ✅ All values are correct! Only allowed values present.
# ==================================================
# ==================================================
# 📊 CORRECT UNITS ANALYSIS: df_tests
# ==================================================
#
# ❌ PARAMETER: sulfur
#    Oczekiwana jednostka: mg/kg
#    Znaleziono błędne jednostki:
#       • ID: TST-000014 → jednostka: sulfur
#       • ID: TST-000811 → jednostka: sulfur
#       • ID: TST-001141 → jednostka: sulfur
#       • ID: TST-001202 → jednostka: sulfur
#       • ID: TST-001316 → jednostka: sulfur
#       • ID: TST-001515 → jednostka: sulfur
#       • ID: TST-001729 → jednostka: sulfur
#       • ID: TST-002026 → jednostka: sulfur
#       • ID: TST-002255 → jednostka: sulfur
#       • ID: TST-002292 → jednostka: sulfur
#       • ID: TST-002346 → jednostka: sulfur
#       • ID: TST-002539 → jednostka: sulfur
#       • ID: TST-002564 → jednostka: sulfur
#       • ID: TST-003007 → jednostka: sulfur
#       • ID: TST-003081 → jednostka: sulfur
#       • ID: TST-003166 → jednostka: sulfur
#       • ID: TST-003518 → jednostka: sulfur
#       • ID: TST-003582 → jednostka: sulfur
#
# ❌ PARAMETER: water
#    Oczekiwana jednostka: mg/kg
#    Znaleziono błędne jednostki:
#       • ID: TST-000050 → jednostka: water
#       • ID: TST-000259 → jednostka: water
#       • ID: TST-000355 → jednostka: water
#       • ID: TST-000375 → jednostka: water
#       • ID: TST-000715 → jednostka: water
#       • ID: TST-000854 → jednostka: water
#       • ID: TST-000924 → jednostka: water
#       • ID: TST-000931 → jednostka: water
#       • ID: TST-001137 → jednostka: water
#       • ID: TST-001374 → jednostka: water
#       • ID: TST-001471 → jednostka: water
#       • ID: TST-001593 → jednostka: water
#       • ID: TST-001713 → jednostka: water
#       • ID: TST-001838 → jednostka: water
#       • ID: TST-001939 → jednostka: water
#       • ID: TST-002326 → jednostka: water
#       • ID: TST-002336 → jednostka: water
#       • ID: TST-003118 → jednostka: water
#       • ID: TST-003237 → jednostka: water
#       • ID: TST-003314 → jednostka: water
#       • ID: TST-003354 → jednostka: water
#       • ID: TST-003467 → jednostka: water
#
# ❌ PARAMETER: density
#    Oczekiwana jednostka: kg/m3
#    Znaleziono błędne jednostki:
#       • ID: TST-000045 → jednostka: density
#       • ID: TST-000081 → jednostka: density
#       • ID: TST-000170 → jednostka: density
#       • ID: TST-000738 → jednostka: density
#       • ID: TST-001047 → jednostka: density
#       • ID: TST-001394 → jednostka: density
#       • ID: TST-001756 → jednostka: density
#       • ID: TST-001778 → jednostka: density
#       • ID: TST-001808 → jednostka: density
#       • ID: TST-001916 → jednostka: density
#       • ID: TST-002052 → jednostka: density
#       • ID: TST-002096 → jednostka: density
#       • ID: TST-002113 → jednostka: density
#       • ID: TST-002196 → jednostka: density
#       • ID: TST-002417 → jednostka: density
#       • ID: TST-002675 → jednostka: density
#       • ID: TST-002893 → jednostka: density
#       • ID: TST-002975 → jednostka: density
#       • ID: TST-003039 → jednostka: density
#       • ID: TST-003053 → jednostka: density
#       • ID: TST-003605 → jednostka: density
#       • ID: TST-003628 → jednostka: density
#       • ID: TST-003664 → jednostka: density
#
# ❌ PARAMETER: viscosity
#    Oczekiwana jednostka: cSt
#    Znaleziono błędne jednostki:
#       • ID: TST-000185 → jednostka: viscosity
#       • ID: TST-000561 → jednostka: viscosity
#       • ID: TST-000709 → jednostka: viscosity
#       • ID: TST-001282 → jednostka: viscosity
#       • ID: TST-001389 → jednostka: viscosity
#       • ID: TST-002819 → jednostka: viscosity
#       • ID: TST-003261 → jednostka: viscosity
#       • ID: TST-003424 → jednostka: viscosity
#       • ID: TST-003516 → jednostka: viscosity
#
# ❌ PARAMETER: chloride
#    Oczekiwana jednostka: mg/kg
#    Znaleziono błędne jednostki:
#       • ID: TST-000678 → jednostka: chloride
#       • ID: TST-000805 → jednostka: chloride
#       • ID: TST-001091 → jednostka: chloride
#       • ID: TST-001343 → jednostka: chloride
#       • ID: TST-001382 → jednostka: chloride
#       • ID: TST-001551 → jednostka: chloride
#       • ID: TST-002440 → jednostka: chloride
#       • ID: TST-003450 → jednostka: chloride
#       • ID: TST-003581 → jednostka: chloride
#
# ❌ PARAMETER: flash_point
#    Oczekiwana jednostka: C
#    Znaleziono błędne jednostki:
#       • ID: TST-000130 → jednostka: flash_point
#       • ID: TST-000285 → jednostka: flash_point
#       • ID: TST-000410 → jednostka: flash_point
#       • ID: TST-000961 → jednostka: flash_point
#       • ID: TST-001029 → jednostka: flash_point
#       • ID: TST-001098 → jednostka: flash_point
#       • ID: TST-001151 → jednostka: flash_point
#       • ID: TST-001198 → jednostka: flash_point
#       • ID: TST-001601 → jednostka: flash_point
#       • ID: TST-001974 → jednostka: flash_point
#       • ID: TST-002053 → jednostka: flash_point
#       • ID: TST-002476 → jednostka: flash_point
#       • ID: TST-002555 → jednostka: flash_point
#       • ID: TST-002837 → jednostka: flash_point
#       • ID: TST-003117 → jednostka: flash_point
#       • ID: TST-003196 → jednostka: flash_point
#       • ID: TST-003199 → jednostka: flash_point
#       • ID: TST-003375 → jednostka: flash_point
#       • ID: TST-003763 → jednostka: flash_point
