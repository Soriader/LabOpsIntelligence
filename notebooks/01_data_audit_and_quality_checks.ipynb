# %%
import pandas as pd
import numpy as np
import DataInspector as di

# ========================================================================================================================
# Load raw data
# ========================================================================================================================

df_lab_events = pd.read_csv('../data/raw/lab_events.csv', encoding='utf-8')
df_samples = pd.read_csv('../data/raw/samples.csv', encoding='utf-8')
df_tests = pd.read_csv('../data/raw/tests.csv', encoding='utf-8')

# ========================================================================================================================
# Number of rows and columns, unique and correct values in sample_id, priority and client_name in samples
# ========================================================================================================================
di.DataInspector.display_dimensions(df_samples, "df_samples")
di.DataInspector.display_unique_value(df_samples, "df_samples","sample_id")
di.DataInspector.display_unique_value(df_samples, "df_samples","priority")
di.DataInspector.display_correct_value(df_samples, "df_samples","priority", ["normal", "high", "urgent"])
di.DataInspector.display_unique_value(df_samples, "df_samples","client_name")

# ========================================================================================================================
# Number of null value in priority and client_name in samples
# ========================================================================================================================
di.DataInspector.display_null_value(df_samples, "df_samples", "client_name")
di.DataInspector.display_null_value(df_samples, "df_samples", "priority")

# ========================================================================================================================
# Number of rows and columns, null value in result_value and unit coherence in tests
# ========================================================================================================================
di.DataInspector.display_dimensions(df_tests, "df_tests")
di.DataInspector.display_unique_value(df_tests, "df_tests","result_value")
di.DataInspector.display_unique_value(df_tests, "df_tests","unit")

# ========================================================================================================================
# Checking the null value in result_value, unit and analyst
# ========================================================================================================================
di.DataInspector.display_null_value(df_tests, "df_tests", "result_value")
di.DataInspector.display_null_value(df_tests, "df_tests", "unit")
di.DataInspector.display_null_value(df_tests, "df_tests", "analyst")

# ========================================================================================================================
# Checking unique and correct values status in tests
# ========================================================================================================================
UNIT_RULES = {
    "sulfur": "mg/kg",
    "water": "mg/kg",
    "density": "kg/m3",
    "viscosity": "cSt",
    "chloride": "mg/kg",
    "flash_point": "C",
}

di.DataInspector.display_correct_value(df_tests, "df_tests","status", ["OK", "ERROR", "RETEST"])
di.DataInspector.units_correctness(df_tests, "df_tests", "parameter", UNIT_RULES)
di.DataInspector.unlogical_combination(df_tests, "df_tests", "status", "result_value")
di.DataInspector.duplicated_in_tests(df_tests, "df_tests", "test_id", "parameter")
di.DataInspector.find_outliers(df_tests, "df_tests", "unit", "result_value")


# ========================================================================================================================
# Checking the correctness of the time in lab_events
# ========================================================================================================================
# Out:
# ==================================================
# 📊 df_samples
# ==================================================
# 📈 Rows: 900
# 📑 Columns: 6
# 💾 Size: 900 × 6
# ==================================================
# ==================================================
# 📊 UNIQUE VALUES ANALYSIS: df_samples
# 📍 Column: sample_id
# ==================================================
# 📈 Total unique values: 900 / 900 (100.00%)
#
# 🔍 Unique values (first 20):
#    1. SMP-00001
#    2. SMP-00002
#    3. SMP-00003
#    4. SMP-00004
#    5. SMP-00005
#    6. SMP-00006
#    7. SMP-00007
#    8. SMP-00008
#    9. SMP-00009
#    10. SMP-00010
#    11. SMP-00011
#    12. SMP-00012
#    13. SMP-00013
#    14. SMP-00014
#    15. SMP-00015
#    16. SMP-00016
#    17. SMP-00017
#    18. SMP-00018
#    19. SMP-00019
#    20. SMP-00020
#    ... and 880 more
# ==================================================
# ==================================================
# 📊 UNIQUE VALUES ANALYSIS: df_samples
# 📍 Column: priority
# ==================================================
# 📈 Total unique values: 6 / 900 (0.67%)
#
# 🔍 Unique values (first 6):
#    1. high
#    2. normal
#    3. urgent
#    4. nan
#    5. rush
#    6. low
#    7. NORMAL
# ==================================================
# ==================================================
# 📊 PRIORITY VALIDATION: df_samples
# 📍 Column: priority
# ==================================================
# 📈 Allowed values: normal, high, urgent
# 🔍 Found unique values: high, normal, urgent, nan, rush, low, NORMAL
#
# ❌ INCORRECT values found: nan, rush, low, NORMAL
# 📊 Count of incorrect records: 4
# ==================================================
# ==================================================
# 📊 UNIQUE VALUES ANALYSIS: df_samples
# 📍 Column: client_name
# ==================================================
# 📈 Total unique values: 6 / 900 (0.67%)
#
# 🔍 Unique values (first 6):
#    1. NordFuel
#    2. Baltic Energy
#    3. FuelCore
#    4. Orlenex
#    5. nan
#    6. ChemTrans
#    7. PetroMax
# ==================================================
# ==================================================
# 📊 NULL ANALYSIS: df_samples
# ==================================================
# 📈 Nulls in 'client_name': 18 (2.00%)
# ==================================================
# ==================================================
# 📊 NULL ANALYSIS: df_samples
# ==================================================
# 📈 Nulls in 'priority': 3 (0.33%)
# ==================================================
# ==================================================
# 📊 df_tests
# ==================================================
# 📈 Rows: 3,867
# 📑 Columns: 8
# 💾 Size: 3,867 × 8
# ==================================================
# ==================================================
# 📊 UNIQUE VALUES ANALYSIS: df_tests
# 📍 Column: result_value
# ==================================================
# 📈 Total unique values: 3,494 / 3,867 (90.35%)
#
# 🔍 Unique values (first 20):
#    1. 77.68
#    2. 363.2
#    3. 861.68
#    4. 104.47
#    5. 14.84
#    6. 70.0
#    7. 531.84
#    8. 731.91
#    9. 102.81
#    10. 15.48
#    11. 46.49
#    12. 919.76
#    13. 45.5
#    14. 14.59
#    15. 28.33
#    16. 220.39
#    17. 732.25
#    18. 69.23
#    19. 410.62
#    20. 808.45
#    ... and 3474 more
# ==================================================
# ==================================================
# 📊 UNIQUE VALUES ANALYSIS: df_tests
# 📍 Column: unit
# ==================================================
# 📈 Total unique values: 7 / 3,867 (0.18%)
#
# 🔍 Unique values (first 7):
#    1. mg/kg
#    2. kg/m3
#    3. cSt
#    4. C
#    5. ppm
#    6. nan
#    7. mg/L
#    8. %
# ==================================================
# ==================================================
# 📊 NULL ANALYSIS: df_samples
# ==================================================
# 📈 Nulls in 'result_value': 80 (2.07%)
# ==================================================
# ==================================================
# 📊 NULL ANALYSIS: df_samples
# ==================================================
# 📈 Nulls in 'unit': 35 (0.91%)
# ==================================================
# ==================================================
# 📊 NULL ANALYSIS: df_samples
# ==================================================
# 📈 Nulls in 'analyst': 26 (0.67%)
# ==================================================
# ==================================================
# 📊 PRIORITY VALIDATION: df_tests
# 📍 Column: status
# ==================================================
# 📈 Allowed values: OK, ERROR, RETEST
# 🔍 Found unique values: ERROR, OK, RETEST
#
# ✅ All values are correct! Only allowed values present.
# ==================================================
# ==================================================
# 📊 CORRECT UNITS ANALYSIS: df_tests
# ==================================================
#
# ❌ PARAMETER: sulfur
#    Expected unit: mg/kg
#    Find wrong units:
#       • ID: TST-000014 → unit: sulfur
#       • ID: TST-000811 → unit: sulfur
#       • ID: TST-001141 → unit: sulfur
#       • ID: TST-001202 → unit: sulfur
#       • ID: TST-001316 → unit: sulfur
#       • ID: TST-001515 → unit: sulfur
#       • ID: TST-001729 → unit: sulfur
#       • ID: TST-002026 → unit: sulfur
#       • ID: TST-002255 → unit: sulfur
#       • ID: TST-002292 → unit: sulfur
#       • ID: TST-002346 → unit: sulfur
#       • ID: TST-002539 → unit: sulfur
#       • ID: TST-002564 → unit: sulfur
#       • ID: TST-003007 → unit: sulfur
#       • ID: TST-003081 → unit: sulfur
#       • ID: TST-003166 → unit: sulfur
#       • ID: TST-003518 → unit: sulfur
#       • ID: TST-003582 → unit: sulfur
#
# ❌ PARAMETER: water
#    Expected unit: mg/kg
#    Find wrong units:
#       • ID: TST-000050 → unit: water
#       • ID: TST-000259 → unit: water
#       • ID: TST-000355 → unit: water
#       • ID: TST-000375 → unit: water
#       • ID: TST-000715 → unit: water
#       • ID: TST-000854 → unit: water
#       • ID: TST-000924 → unit: water
#       • ID: TST-000931 → unit: water
#       • ID: TST-001137 → unit: water
#       • ID: TST-001374 → unit: water
#       • ID: TST-001471 → unit: water
#       • ID: TST-001593 → unit: water
#       • ID: TST-001713 → unit: water
#       • ID: TST-001838 → unit: water
#       • ID: TST-001939 → unit: water
#       • ID: TST-002326 → unit: water
#       • ID: TST-002336 → unit: water
#       • ID: TST-003118 → unit: water
#       • ID: TST-003237 → unit: water
#       • ID: TST-003314 → unit: water
#       • ID: TST-003354 → unit: water
#       • ID: TST-003467 → unit: water
#
# ❌ PARAMETER: density
#    Expected unit: kg/m3
#    Find wrong units:
#       • ID: TST-000045 → unit: density
#       • ID: TST-000081 → unit: density
#       • ID: TST-000170 → unit: density
#       • ID: TST-000738 → unit: density
#       • ID: TST-001047 → unit: density
#       • ID: TST-001394 → unit: density
#       • ID: TST-001756 → unit: density
#       • ID: TST-001778 → unit: density
#       • ID: TST-001808 → unit: density
#       • ID: TST-001916 → unit: density
#       • ID: TST-002052 → unit: density
#       • ID: TST-002096 → unit: density
#       • ID: TST-002113 → unit: density
#       • ID: TST-002196 → unit: density
#       • ID: TST-002417 → unit: density
#       • ID: TST-002675 → unit: density
#       • ID: TST-002893 → unit: density
#       • ID: TST-002975 → unit: density
#       • ID: TST-003039 → unit: density
#       • ID: TST-003053 → unit: density
#       • ID: TST-003605 → unit: density
#       • ID: TST-003628 → unit: density
#       • ID: TST-003664 → unit: density
#
# ❌ PARAMETER: viscosity
#    Expected unit: cSt
#    Find wrong units:
#       • ID: TST-000185 → unit: viscosity
#       • ID: TST-000561 → unit: viscosity
#       • ID: TST-000709 → unit: viscosity
#       • ID: TST-001282 → unit: viscosity
#       • ID: TST-001389 → unit: viscosity
#       • ID: TST-002819 → unit: viscosity
#       • ID: TST-003261 → unit: viscosity
#       • ID: TST-003424 → unit: viscosity
#       • ID: TST-003516 → unit: viscosity
#
# ❌ PARAMETER: chloride
#    Expected unit: mg/kg
#    Find wrong units:
#       • ID: TST-000678 → unit: chloride
#       • ID: TST-000805 → unit: chloride
#       • ID: TST-001091 → unit: chloride
#       • ID: TST-001343 → unit: chloride
#       • ID: TST-001382 → unit: chloride
#       • ID: TST-001551 → unit: chloride
#       • ID: TST-002440 → unit: chloride
#       • ID: TST-003450 → unit: chloride
#       • ID: TST-003581 → unit: chloride
#
# ❌ PARAMETER: flash_point
#    Expected unit: C
#    Find wrong units:
#       • ID: TST-000130 → unit: flash_point
#       • ID: TST-000285 → unit: flash_point
#       • ID: TST-000410 → unit: flash_point
#       • ID: TST-000961 → unit: flash_point
#       • ID: TST-001029 → unit: flash_point
#       • ID: TST-001098 → unit: flash_point
#       • ID: TST-001151 → unit: flash_point
#       • ID: TST-001198 → unit: flash_point
#       • ID: TST-001601 → unit: flash_point
#       • ID: TST-001974 → unit: flash_point
#       • ID: TST-002053 → unit: flash_point
#       • ID: TST-002476 → unit: flash_point
#       • ID: TST-002555 → unit: flash_point
#       • ID: TST-002837 → unit: flash_point
#       • ID: TST-003117 → unit: flash_point
#       • ID: TST-003196 → unit: flash_point
#       • ID: TST-003199 → unit: flash_point
#       • ID: TST-003375 → unit: flash_point
#       • ID: TST-003763 → unit: flash_point
# ==================================================
# 📊 LOGICAL COMBINATION VALIDATION: df_tests
# ==================================================
# ❌ ID: TST-000001 - Status 'ERROR' but result_value exists: 77.68
# ❌ ID: TST-000026 - Status 'ERROR' but result_value exists: 33.35
# ❌ ID: TST-000036 - Status 'ERROR' but result_value exists: 33.65
# ❌ ID: TST-000037 - Status 'ERROR' but result_value exists: 556.19
# ❌ ID: TST-000051 - Status 'OK' but result_value is missing
# ❌ ID: TST-000061 - Status 'ERROR' but result_value exists: 748.1
# ❌ ID: TST-000062 - Status 'ERROR' but result_value exists: 98.21
# ❌ ID: TST-000071 - Status 'ERROR' but result_value exists: 130.06
# ❌ ID: TST-000076 - Status 'ERROR' but result_value exists: 827.75
# ❌ ID: TST-000090 - Status 'ERROR' but result_value exists: 49.09
# ❌ ID: TST-000105 - Status 'ERROR' but result_value exists: 29.69
# ❌ ID: TST-000122 - Status 'OK' but result_value is missing
# ❌ ID: TST-000129 - Status 'ERROR' but result_value exists: 951.25
# ❌ ID: TST-000149 - Status 'ERROR' but result_value exists: 24.48
# ❌ ID: TST-000157 - Status 'ERROR' but result_value exists: 148.29
# ❌ ID: TST-000159 - Status 'ERROR' but result_value exists: 66.14
# ❌ ID: TST-000176 - Status 'ERROR' but result_value exists: 27.89
# ❌ ID: TST-000202 - Status 'ERROR' but result_value exists: 932.79
# ❌ ID: TST-000204 - Status 'ERROR' but result_value exists: 17.06
# ❌ ID: TST-000241 - Status 'OK' but result_value is missing
# ❌ ID: TST-000242 - Status 'ERROR' but result_value exists: 92.78
# ❌ ID: TST-000249 - Status 'ERROR' but result_value exists: 91.86
# ❌ ID: TST-000251 - Status 'ERROR' but result_value exists: 228.07
# ❌ ID: TST-000254 - Status 'ERROR' but result_value exists: 37.18
# ❌ ID: TST-000257 - Status 'ERROR' but result_value exists: 66.08
# ❌ ID: TST-000263 - Status 'ERROR' but result_value exists: 42.54
# ❌ ID: TST-000282 - Status 'ERROR' but result_value exists: 85.28
# ❌ ID: TST-000286 - Status 'ERROR' but result_value exists: 31.66
# ❌ ID: TST-000299 - Status 'ERROR' but result_value exists: 162.71
# ❌ ID: TST-000319 - Status 'OK' but result_value is missing
# ❌ ID: TST-000340 - Status 'ERROR' but result_value exists: 41.87
# ❌ ID: TST-000341 - Status 'ERROR' but result_value exists: 844.14
# ❌ ID: TST-000360 - Status 'ERROR' but result_value exists: 810.0
# ❌ ID: TST-000382 - Status 'OK' but result_value is missing
# ❌ ID: TST-000384 - Status 'ERROR' but result_value exists: 82.56
# ❌ ID: TST-000394 - Status 'ERROR' but result_value exists: 43.34
# ❌ ID: TST-000397 - Status 'ERROR' but result_value exists: 25.35
# ❌ ID: TST-000407 - Status 'OK' but result_value is missing
# ❌ ID: TST-000421 - Status 'ERROR' but result_value exists: 940.42
# ❌ ID: TST-000444 - Status 'ERROR' but result_value exists: 293.34
# ❌ ID: TST-000459 - Status 'ERROR' but result_value exists: 61.18
# ❌ ID: TST-000460 - Status 'ERROR' but result_value exists: 311.79
# ❌ ID: TST-000477 - Status 'OK' but result_value is missing
# ❌ ID: TST-000484 - Status 'OK' but result_value is missing
# ❌ ID: TST-000496 - Status 'ERROR' but result_value exists: 150.51
# ❌ ID: TST-000501 - Status 'ERROR' but result_value exists: 189.87
# ❌ ID: TST-000505 - Status 'ERROR' but result_value exists: 47.7
# ❌ ID: TST-000516 - Status 'ERROR' but result_value exists: 730.49
# ❌ ID: TST-000525 - Status 'ERROR' but result_value exists: 67.07
# ❌ ID: TST-000531 - Status 'ERROR' but result_value exists: 735.23
# ❌ ID: TST-000533 - Status 'ERROR' but result_value exists: 11.28
# ❌ ID: TST-000563 - Status 'OK' but result_value is missing
# ❌ ID: TST-000570 - Status 'OK' but result_value is missing
# ❌ ID: TST-000575 - Status 'ERROR' but result_value exists: 527.35
# ❌ ID: TST-000579 - Status 'ERROR' but result_value exists: 412.49
# ❌ ID: TST-000588 - Status 'ERROR' but result_value exists: 25.28
# ❌ ID: TST-000595 - Status 'ERROR' but result_value exists: 904.88
# ❌ ID: TST-000601 - Status 'OK' but result_value is missing
# ❌ ID: TST-000654 - Status 'ERROR' but result_value exists: 43.98
# ❌ ID: TST-000667 - Status 'ERROR' but result_value exists: 44.24
# ❌ ID: TST-000668 - Status 'ERROR' but result_value exists: 726.57
# ❌ ID: TST-000674 - Status 'ERROR' but result_value exists: 424.25
# ❌ ID: TST-000687 - Status 'ERROR' but result_value exists: 928.73
# ❌ ID: TST-000694 - Status 'ERROR' but result_value exists: 37.28
# ❌ ID: TST-000698 - Status 'ERROR' but result_value exists: 115.23
# ❌ ID: TST-000703 - Status 'ERROR' but result_value exists: 112.91
# ❌ ID: TST-000704 - Status 'ERROR' but result_value exists: 962.42
# ❌ ID: TST-000712 - Status 'ERROR' but result_value exists: 910.72
# ❌ ID: TST-000727 - Status 'ERROR' but result_value exists: 19.83
# ❌ ID: TST-000732 - Status 'OK' but result_value is missing
# ❌ ID: TST-000733 - Status 'ERROR' but result_value exists: 882.04
# ❌ ID: TST-000743 - Status 'ERROR' but result_value exists: 870.28
# ❌ ID: TST-000752 - Status 'ERROR' but result_value exists: 100.0
# ❌ ID: TST-000761 - Status 'ERROR' but result_value exists: 51.46
# ❌ ID: TST-000766 - Status 'ERROR' but result_value exists: 29.1
# ❌ ID: TST-000774 - Status 'ERROR' but result_value exists: 958.16
# ❌ ID: TST-000786 - Status 'ERROR' but result_value exists: 521.08
# ❌ ID: TST-000798 - Status 'ERROR' but result_value exists: 25.38
# ❌ ID: TST-000806 - Status 'OK' but result_value is missing
# ❌ ID: TST-000811 - Status 'ERROR' but result_value exists: 10.08
# ❌ ID: TST-000812 - Status 'OK' but result_value is missing
# ❌ ID: TST-000820 - Status 'OK' but result_value is missing
# ❌ ID: TST-000838 - Status 'ERROR' but result_value exists: 29.19
# ❌ ID: TST-000839 - Status 'ERROR' but result_value exists: 776.13
# ❌ ID: TST-000842 - Status 'ERROR' but result_value exists: 862.99
# ❌ ID: TST-000843 - Status 'OK' but result_value is missing
# ❌ ID: TST-000844 - Status 'OK' but result_value is missing
# ❌ ID: TST-000851 - Status 'ERROR' but result_value exists: 786.62
# ❌ ID: TST-000869 - Status 'ERROR' but result_value exists: 723.57
# ❌ ID: TST-000875 - Status 'ERROR' but result_value exists: 81.38
# ❌ ID: TST-000914 - Status 'OK' but result_value is missing
# ❌ ID: TST-000934 - Status 'ERROR' but result_value exists: -5.0
# ❌ ID: TST-000944 - Status 'ERROR' but result_value exists: 407.65
# ❌ ID: TST-000947 - Status 'ERROR' but result_value exists: 80.14
# ❌ ID: TST-000949 - Status 'ERROR' but result_value exists: 10.4
# ❌ ID: TST-000954 - Status 'ERROR' but result_value exists: 880.24
# ❌ ID: TST-000965 - Status 'ERROR' but result_value exists: 54.05
# ❌ ID: TST-000974 - Status 'ERROR' but result_value exists: 80.98
# ❌ ID: TST-000979 - Status 'ERROR' but result_value exists: 558.54
# ❌ ID: TST-000995 - Status 'ERROR' but result_value exists: 38.38
# ❌ ID: TST-001017 - Status 'ERROR' but result_value exists: 886.49
# ❌ ID: TST-001052 - Status 'ERROR' but result_value exists: 63.53
# ❌ ID: TST-001053 - Status 'ERROR' but result_value exists: 6.46
# ❌ ID: TST-001061 - Status 'OK' but result_value is missing
# ❌ ID: TST-001068 - Status 'ERROR' but result_value exists: 225.4
# ❌ ID: TST-001070 - Status 'ERROR' but result_value exists: 5.09
# ❌ ID: TST-001075 - Status 'OK' but result_value is missing
# ❌ ID: TST-001076 - Status 'ERROR' but result_value exists: 68.03
# ❌ ID: TST-001096 - Status 'ERROR' but result_value exists: 366.85
# ❌ ID: TST-001106 - Status 'ERROR' but result_value exists: 56.89
# ❌ ID: TST-001107 - Status 'ERROR' but result_value exists: 67.64
# ❌ ID: TST-001108 - Status 'ERROR' but result_value exists: 124.75
# ❌ ID: TST-001111 - Status 'ERROR' but result_value exists: 57.75
# ❌ ID: TST-001112 - Status 'OK' but result_value is missing
# ❌ ID: TST-001131 - Status 'OK' but result_value is missing
# ❌ ID: TST-001140 - Status 'ERROR' but result_value exists: 84.58
# ❌ ID: TST-001153 - Status 'ERROR' but result_value exists: 47.77
# ❌ ID: TST-001157 - Status 'ERROR' but result_value exists: 70.89
# ❌ ID: TST-001160 - Status 'OK' but result_value is missing
# ❌ ID: TST-001162 - Status 'ERROR' but result_value exists: 152.33
# ❌ ID: TST-001169 - Status 'ERROR' but result_value exists: 101.04
# ❌ ID: TST-001175 - Status 'ERROR' but result_value exists: 50.42
# ❌ ID: TST-001179 - Status 'OK' but result_value is missing
# ❌ ID: TST-001186 - Status 'ERROR' but result_value exists: 950.29
# ❌ ID: TST-001193 - Status 'ERROR' but result_value exists: 64.58
# ❌ ID: TST-001206 - Status 'ERROR' but result_value exists: 771.65
# ❌ ID: TST-001213 - Status 'ERROR' but result_value exists: 54.41
# ❌ ID: TST-001228 - Status 'OK' but result_value is missing
# ❌ ID: TST-001230 - Status 'ERROR' but result_value exists: 78.47
# ❌ ID: TST-001253 - Status 'ERROR' but result_value exists: 858.94
# ❌ ID: TST-001269 - Status 'ERROR' but result_value exists: 841.8
# ❌ ID: TST-001271 - Status 'ERROR' but result_value exists: 31.47
# ❌ ID: TST-001277 - Status 'ERROR' but result_value exists: 877.12
# ❌ ID: TST-001309 - Status 'ERROR' but result_value exists: 753.05
# ❌ ID: TST-001311 - Status 'ERROR' but result_value exists: 85.02
# ❌ ID: TST-001320 - Status 'ERROR' but result_value exists: 345.34
# ❌ ID: TST-001340 - Status 'ERROR' but result_value exists: 436.42
# ❌ ID: TST-001341 - Status 'ERROR' but result_value exists: 851.25
# ❌ ID: TST-001342 - Status 'ERROR' but result_value exists: 76.66
# ❌ ID: TST-001345 - Status 'ERROR' but result_value exists: 918.24
# ❌ ID: TST-001362 - Status 'ERROR' but result_value exists: 771.19
# ❌ ID: TST-001409 - Status 'ERROR' but result_value exists: 64.26
# ❌ ID: TST-001410 - Status 'ERROR' but result_value exists: 12.07
# ❌ ID: TST-001415 - Status 'ERROR' but result_value exists: 443.99
# ❌ ID: TST-001422 - Status 'ERROR' but result_value exists: 26.74
# ❌ ID: TST-001443 - Status 'ERROR' but result_value exists: 821.56
# ❌ ID: TST-001446 - Status 'ERROR' but result_value exists: 149.99
# ❌ ID: TST-001465 - Status 'ERROR' but result_value exists: 770.04
# ❌ ID: TST-001483 - Status 'OK' but result_value is missing
# ❌ ID: TST-001484 - Status 'ERROR' but result_value exists: 463.73
# ❌ ID: TST-001491 - Status 'ERROR' but result_value exists: 63.66
# ❌ ID: TST-001508 - Status 'ERROR' but result_value exists: 129.85
# ❌ ID: TST-001528 - Status 'ERROR' but result_value exists: 778.52
# ❌ ID: TST-001534 - Status 'ERROR' but result_value exists: 962.99
# ❌ ID: TST-001536 - Status 'ERROR' but result_value exists: 39.92
# ❌ ID: TST-001590 - Status 'ERROR' but result_value exists: 721.53
# ❌ ID: TST-001591 - Status 'OK' but result_value is missing
# ❌ ID: TST-001594 - Status 'OK' but result_value is missing
# ❌ ID: TST-001601 - Status 'OK' but result_value is missing
# ❌ ID: TST-001635 - Status 'ERROR' but result_value exists: 970.96
# ❌ ID: TST-001641 - Status 'ERROR' but result_value exists: 413.98
# ❌ ID: TST-001645 - Status 'OK' but result_value is missing
# ❌ ID: TST-001647 - Status 'ERROR' but result_value exists: 87.84
# ❌ ID: TST-001648 - Status 'ERROR' but result_value exists: 799.92
# ❌ ID: TST-001650 - Status 'ERROR' but result_value exists: 164.45
# ❌ ID: TST-001666 - Status 'ERROR' but result_value exists: 180.34
# ❌ ID: TST-001667 - Status 'ERROR' but result_value exists: 962.15
# ❌ ID: TST-001668 - Status 'OK' but result_value is missing
# ❌ ID: TST-001678 - Status 'ERROR' but result_value exists: 283.72
# ❌ ID: TST-001684 - Status 'ERROR' but result_value exists: 84.97
# ❌ ID: TST-001722 - Status 'OK' but result_value is missing
# ❌ ID: TST-001728 - Status 'ERROR' but result_value exists: 75.5
# ❌ ID: TST-001731 - Status 'OK' but result_value is missing
# ❌ ID: TST-001736 - Status 'OK' but result_value is missing
# ❌ ID: TST-001759 - Status 'ERROR' but result_value exists: 155.57
# ❌ ID: TST-001774 - Status 'ERROR' but result_value exists: 746.71
# ❌ ID: TST-001776 - Status 'ERROR' but result_value exists: 21.14
# ❌ ID: TST-001783 - Status 'OK' but result_value is missing
# ❌ ID: TST-001787 - Status 'ERROR' but result_value exists: 33.45
# ❌ ID: TST-001789 - Status 'ERROR' but result_value exists: 782.55
# ❌ ID: TST-001807 - Status 'ERROR' but result_value exists: 89.27
# ❌ ID: TST-001813 - Status 'ERROR' but result_value exists: 926.79
# ❌ ID: TST-001814 - Status 'OK' but result_value is missing
# ❌ ID: TST-001817 - Status 'ERROR' but result_value exists: 25.95
# ❌ ID: TST-001822 - Status 'OK' but result_value is missing
# ❌ ID: TST-001831 - Status 'ERROR' but result_value exists: 507.84
# ❌ ID: TST-001866 - Status 'OK' but result_value is missing
# ❌ ID: TST-001884 - Status 'OK' but result_value is missing
# ❌ ID: TST-001895 - Status 'ERROR' but result_value exists: 26.23
# ❌ ID: TST-001901 - Status 'OK' but result_value is missing
# ❌ ID: TST-001906 - Status 'ERROR' but result_value exists: 55.32
# ❌ ID: TST-001925 - Status 'OK' but result_value is missing
# ❌ ID: TST-001928 - Status 'ERROR' but result_value exists: 766.78
# ❌ ID: TST-001944 - Status 'ERROR' but result_value exists: 295.58
# ❌ ID: TST-001953 - Status 'OK' but result_value is missing
# ❌ ID: TST-001959 - Status 'ERROR' but result_value exists: 847.46
# ❌ ID: TST-001963 - Status 'ERROR' but result_value exists: 876.28
# ❌ ID: TST-001987 - Status 'ERROR' but result_value exists: 42.46
# ❌ ID: TST-001995 - Status 'ERROR' but result_value exists: 196.82
# ❌ ID: TST-002014 - Status 'ERROR' but result_value exists: 89.75
# ❌ ID: TST-002024 - Status 'ERROR' but result_value exists: 829.09
# ❌ ID: TST-002026 - Status 'ERROR' but result_value exists: 43.07
# ❌ ID: TST-002035 - Status 'ERROR' but result_value exists: 800.02
# ❌ ID: TST-002068 - Status 'ERROR' but result_value exists: 2.65
# ❌ ID: TST-002071 - Status 'ERROR' but result_value exists: 749.03
# ❌ ID: TST-002075 - Status 'ERROR' but result_value exists: 785.6
# ❌ ID: TST-002086 - Status 'ERROR' but result_value exists: 1500.0
# ❌ ID: TST-002098 - Status 'ERROR' but result_value exists: 56.56
# ❌ ID: TST-002126 - Status 'ERROR' but result_value exists: 905.59
# ❌ ID: TST-002144 - Status 'OK' but result_value is missing
# ❌ ID: TST-002150 - Status 'ERROR' but result_value exists: 25.5
# ❌ ID: TST-002156 - Status 'ERROR' but result_value exists: 760.85
# ❌ ID: TST-002170 - Status 'ERROR' but result_value exists: 912.16
# ❌ ID: TST-002181 - Status 'ERROR' but result_value exists: 56.51
# ❌ ID: TST-002183 - Status 'ERROR' but result_value exists: 348.23
# ❌ ID: TST-002188 - Status 'ERROR' but result_value exists: 269.15
# ❌ ID: TST-002198 - Status 'ERROR' but result_value exists: 446.47
# ❌ ID: TST-002233 - Status 'OK' but result_value is missing
# ❌ ID: TST-002238 - Status 'ERROR' but result_value exists: 282.58
# ❌ ID: TST-002247 - Status 'ERROR' but result_value exists: 4.75
# ❌ ID: TST-002249 - Status 'ERROR' but result_value exists: 316.05
# ❌ ID: TST-002257 - Status 'ERROR' but result_value exists: 880.26
# ❌ ID: TST-002263 - Status 'ERROR' but result_value exists: 808.44
# ❌ ID: TST-002298 - Status 'OK' but result_value is missing
# ❌ ID: TST-002313 - Status 'ERROR' but result_value exists: 316.77
# ❌ ID: TST-002319 - Status 'ERROR' but result_value exists: 937.82
# ❌ ID: TST-002327 - Status 'ERROR' but result_value exists: 841.93
# ❌ ID: TST-002344 - Status 'ERROR' but result_value exists: 725.44
# ❌ ID: TST-002350 - Status 'ERROR' but result_value exists: 32.31
# ❌ ID: TST-002356 - Status 'ERROR' but result_value exists: 76.15
# ❌ ID: TST-002358 - Status 'ERROR' but result_value exists: 546.0
# ❌ ID: TST-002367 - Status 'ERROR' but result_value exists: 46.95
# ❌ ID: TST-002377 - Status 'ERROR' but result_value exists: 965.16
# ❌ ID: TST-002382 - Status 'ERROR' but result_value exists: 971.07
# ❌ ID: TST-002388 - Status 'ERROR' but result_value exists: 32.48
# ❌ ID: TST-002397 - Status 'ERROR' but result_value exists: 24.79
# ❌ ID: TST-002451 - Status 'ERROR' but result_value exists: 86.54
# ❌ ID: TST-002461 - Status 'ERROR' but result_value exists: 69.72
# ❌ ID: TST-002464 - Status 'ERROR' but result_value exists: 847.02
# ❌ ID: TST-002470 - Status 'ERROR' but result_value exists: 958.76
# ❌ ID: TST-002485 - Status 'ERROR' but result_value exists: 48.97
# ❌ ID: TST-002496 - Status 'ERROR' but result_value exists: 848.27
# ❌ ID: TST-002510 - Status 'ERROR' but result_value exists: 30.53
# ❌ ID: TST-002517 - Status 'ERROR' but result_value exists: 84.76
# ❌ ID: TST-002529 - Status 'OK' but result_value is missing
# ❌ ID: TST-002541 - Status 'ERROR' but result_value exists: 270.47
# ❌ ID: TST-002552 - Status 'ERROR' but result_value exists: 20.13
# ❌ ID: TST-002571 - Status 'ERROR' but result_value exists: 914.8
# ❌ ID: TST-002572 - Status 'ERROR' but result_value exists: 108.56
# ❌ ID: TST-002613 - Status 'ERROR' but result_value exists: 49.92
# ❌ ID: TST-002621 - Status 'ERROR' but result_value exists: 104.46
# ❌ ID: TST-002634 - Status 'OK' but result_value is missing
# ❌ ID: TST-002642 - Status 'ERROR' but result_value exists: 40.57
# ❌ ID: TST-002650 - Status 'ERROR' but result_value exists: 923.0
# ❌ ID: TST-002652 - Status 'ERROR' but result_value exists: 17.74
# ❌ ID: TST-002653 - Status 'ERROR' but result_value exists: 152.21
# ❌ ID: TST-002654 - Status 'OK' but result_value is missing
# ❌ ID: TST-002662 - Status 'ERROR' but result_value exists: 72.83
# ❌ ID: TST-002664 - Status 'ERROR' but result_value exists: 98.81
# ❌ ID: TST-002698 - Status 'OK' but result_value is missing
# ❌ ID: TST-002730 - Status 'ERROR' but result_value exists: 50.15
# ❌ ID: TST-002731 - Status 'ERROR' but result_value exists: 482.71
# ❌ ID: TST-002742 - Status 'ERROR' but result_value exists: 374.88
# ❌ ID: TST-002758 - Status 'OK' but result_value is missing
# ❌ ID: TST-002759 - Status 'ERROR' but result_value exists: 795.82
# ❌ ID: TST-002765 - Status 'ERROR' but result_value exists: 414.51
# ❌ ID: TST-002770 - Status 'ERROR' but result_value exists: 59.39
# ❌ ID: TST-002773 - Status 'ERROR' but result_value exists: 72.02
# ❌ ID: TST-002774 - Status 'ERROR' but result_value exists: 433.57
# ❌ ID: TST-002775 - Status 'ERROR' but result_value exists: 768.06
# ❌ ID: TST-002778 - Status 'ERROR' but result_value exists: 2.17
# ❌ ID: TST-002791 - Status 'ERROR' but result_value exists: 79.76
# ❌ ID: TST-002793 - Status 'ERROR' but result_value exists: 932.52
# ❌ ID: TST-002796 - Status 'ERROR' but result_value exists: 27.81
# ❌ ID: TST-002797 - Status 'OK' but result_value is missing
# ❌ ID: TST-002816 - Status 'ERROR' but result_value exists: 28.21
# ❌ ID: TST-002830 - Status 'ERROR' but result_value exists: 523.75
# ❌ ID: TST-002845 - Status 'OK' but result_value is missing
# ❌ ID: TST-002852 - Status 'ERROR' but result_value exists: 98.92
# ❌ ID: TST-002853 - Status 'ERROR' but result_value exists: 16.77
# ❌ ID: TST-002867 - Status 'ERROR' but result_value exists: 334.36
# ❌ ID: TST-002868 - Status 'OK' but result_value is missing
# ❌ ID: TST-002874 - Status 'ERROR' but result_value exists: 82.05
# ❌ ID: TST-002879 - Status 'ERROR' but result_value exists: 914.08
# ❌ ID: TST-002890 - Status 'ERROR' but result_value exists: 37.62
# ❌ ID: TST-002892 - Status 'ERROR' but result_value exists: 50000.0
# ❌ ID: TST-002901 - Status 'ERROR' but result_value exists: 864.93
# ❌ ID: TST-002919 - Status 'OK' but result_value is missing
# ❌ ID: TST-002931 - Status 'OK' but result_value is missing
# ❌ ID: TST-002940 - Status 'ERROR' but result_value exists: 29.05
# ❌ ID: TST-002963 - Status 'OK' but result_value is missing
# ❌ ID: TST-002974 - Status 'ERROR' but result_value exists: 154.51
# ❌ ID: TST-002983 - Status 'ERROR' but result_value exists: 7.39
# ❌ ID: TST-003006 - Status 'ERROR' but result_value exists: 51.7
# ❌ ID: TST-003018 - Status 'ERROR' but result_value exists: 8.58
# ❌ ID: TST-003033 - Status 'ERROR' but result_value exists: 33.13
# ❌ ID: TST-003034 - Status 'ERROR' but result_value exists: 15.15
# ❌ ID: TST-003038 - Status 'ERROR' but result_value exists: 588.7
# ❌ ID: TST-003048 - Status 'ERROR' but result_value exists: 551.87
# ❌ ID: TST-003063 - Status 'ERROR' but result_value exists: 59.94
# ❌ ID: TST-003068 - Status 'OK' but result_value is missing
# ❌ ID: TST-003096 - Status 'ERROR' but result_value exists: 28.15
# ❌ ID: TST-003124 - Status 'ERROR' but result_value exists: 50.92
# ❌ ID: TST-003126 - Status 'ERROR' but result_value exists: 866.8
# ❌ ID: TST-003130 - Status 'ERROR' but result_value exists: 953.17
# ❌ ID: TST-003132 - Status 'ERROR' but result_value exists: 13.74
# ❌ ID: TST-003133 - Status 'OK' but result_value is missing
# ❌ ID: TST-003134 - Status 'OK' but result_value is missing
# ❌ ID: TST-003140 - Status 'ERROR' but result_value exists: 36.09
# ❌ ID: TST-003141 - Status 'ERROR' but result_value exists: 39.73
# ❌ ID: TST-003156 - Status 'ERROR' but result_value exists: 28.79
# ❌ ID: TST-003165 - Status 'ERROR' but result_value exists: 57.72
# ❌ ID: TST-003177 - Status 'ERROR' but result_value exists: 36.85
# ❌ ID: TST-003198 - Status 'ERROR' but result_value exists: 822.08
# ❌ ID: TST-003212 - Status 'ERROR' but result_value exists: 452.4
# ❌ ID: TST-003217 - Status 'ERROR' but result_value exists: 56.29
# ❌ ID: TST-003221 - Status 'ERROR' but result_value exists: 791.79
# ❌ ID: TST-003246 - Status 'ERROR' but result_value exists: 35.3
# ❌ ID: TST-003247 - Status 'OK' but result_value is missing
# ❌ ID: TST-003280 - Status 'ERROR' but result_value exists: 77.57
# ❌ ID: TST-003281 - Status 'ERROR' but result_value exists: 61.23
# ❌ ID: TST-003294 - Status 'ERROR' but result_value exists: 69.39
# ❌ ID: TST-003300 - Status 'ERROR' but result_value exists: 27.95
# ❌ ID: TST-003302 - Status 'ERROR' but result_value exists: 66.97
# ❌ ID: TST-003311 - Status 'ERROR' but result_value exists: 71.93
# ❌ ID: TST-003317 - Status 'ERROR' but result_value exists: 6.63
# ❌ ID: TST-003344 - Status 'ERROR' but result_value exists: 958.2
# ❌ ID: TST-003345 - Status 'ERROR' but result_value exists: 74.62
# ❌ ID: TST-003347 - Status 'OK' but result_value is missing
# ❌ ID: TST-003355 - Status 'ERROR' but result_value exists: 844.52
# ❌ ID: TST-003356 - Status 'ERROR' but result_value exists: 24.09
# ❌ ID: TST-003358 - Status 'ERROR' but result_value exists: 14.49
# ❌ ID: TST-003384 - Status 'OK' but result_value is missing
# ❌ ID: TST-003388 - Status 'ERROR' but result_value exists: 57.19
# ❌ ID: TST-003394 - Status 'OK' but result_value is missing
# ❌ ID: TST-003420 - Status 'ERROR' but result_value exists: 80.61
# ❌ ID: TST-003430 - Status 'ERROR' but result_value exists: 18.2
# ❌ ID: TST-003433 - Status 'ERROR' but result_value exists: 825.63
# ❌ ID: TST-003437 - Status 'ERROR' but result_value exists: 860.2
# ❌ ID: TST-003439 - Status 'ERROR' but result_value exists: 76.26
# ❌ ID: TST-003443 - Status 'ERROR' but result_value exists: 864.51
# ❌ ID: TST-003444 - Status 'ERROR' but result_value exists: 81.17
# ❌ ID: TST-003463 - Status 'ERROR' but result_value exists: 863.84
# ❌ ID: TST-003477 - Status 'ERROR' but result_value exists: 555.65
# ❌ ID: TST-003507 - Status 'ERROR' but result_value exists: 102.56
# ❌ ID: TST-003509 - Status 'OK' but result_value is missing
# ❌ ID: TST-003522 - Status 'ERROR' but result_value exists: 39.27
# ❌ ID: TST-003524 - Status 'ERROR' but result_value exists: 808.5
# ❌ ID: TST-003532 - Status 'ERROR' but result_value exists: 915.16
# ❌ ID: TST-003536 - Status 'ERROR' but result_value exists: 53.74
# ❌ ID: TST-003541 - Status 'OK' but result_value is missing
# ❌ ID: TST-003567 - Status 'ERROR' but result_value exists: 83.42
# ❌ ID: TST-003576 - Status 'ERROR' but result_value exists: 86.43
# ❌ ID: TST-003580 - Status 'ERROR' but result_value exists: 87.23
# ❌ ID: TST-003589 - Status 'ERROR' but result_value exists: 24.06
# ❌ ID: TST-003604 - Status 'ERROR' but result_value exists: 390.53
# ❌ ID: TST-003614 - Status 'ERROR' but result_value exists: -20.0
# ❌ ID: TST-003630 - Status 'OK' but result_value is missing
# ❌ ID: TST-003648 - Status 'ERROR' but result_value exists: 35.37
# ❌ ID: TST-003660 - Status 'ERROR' but result_value exists: 881.73
# ❌ ID: TST-003665 - Status 'OK' but result_value is missing
# ❌ ID: TST-003672 - Status 'ERROR' but result_value exists: 818.38
# ❌ ID: TST-003678 - Status 'ERROR' but result_value exists: 435.79
# ❌ ID: TST-003687 - Status 'OK' but result_value is missing
# ❌ ID: TST-003691 - Status 'ERROR' but result_value exists: 949.87
# ❌ ID: TST-003697 - Status 'ERROR' but result_value exists: 55.66
# ❌ ID: TST-003705 - Status 'ERROR' but result_value exists: 821.58
# ❌ ID: TST-003712 - Status 'ERROR' but result_value exists: 509.88
# ❌ ID: TST-003731 - Status 'ERROR' but result_value exists: 29.74
# ❌ ID: TST-003735 - Status 'ERROR' but result_value exists: 47.32
# ❌ ID: TST-003749 - Status 'ERROR' but result_value exists: 847.42
# ❌ ID: TST-003750 - Status 'OK' but result_value is missing
# ❌ ID: TST-003752 - Status 'ERROR' but result_value exists: 722.04
# ❌ ID: TST-003753 - Status 'ERROR' but result_value exists: 4.72
# ❌ ID: TST-003758 - Status 'ERROR' but result_value exists: 41.88
# ❌ ID: TST-003775 - Status 'ERROR' but result_value exists: 27.12
# ❌ ID: TST-003786 - Status 'ERROR' but result_value exists: 9.29
# ❌ ID: TST-003801 - Status 'ERROR' but result_value exists: 12.3
# ❌ ID: TST-003804 - Status 'ERROR' but result_value exists: 873.12
# ❌ ID: TST-003807 - Status 'ERROR' but result_value exists: 175.16
# ❌ ID: TST-003812 - Status 'ERROR' but result_value exists: 8.0
# ❌ ID: TST-003814 - Status 'ERROR' but result_value exists: 44.49
# ❌ ID: TST-003141 - Status 'ERROR' but result_value exists: 39.73
# ❌ ID: TST-003344 - Status 'ERROR' but result_value exists: 958.2
# ❌ ID: TST-002198 - Status 'ERROR' but result_value exists: 446.47
# ❌ ID: TST-003812 - Status 'ERROR' but result_value exists: 8.0
# ❌ ID: TST-003165 - Status 'ERROR' but result_value exists: 57.72
# ❌ ID: TST-001075 - Status 'OK' but result_value is missing
# ❌ ID: TST-000703 - Status 'ERROR' but result_value exists: 112.91
#
# 📈 Total logical errors: 389
# ==================================================
# ==================================================
# 📊 DUPLICATE ANALYSIS
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3862     True
# 3863     True
# 3864     True
# 3865     True
# 3866     True
# Length: 3867, dtype: bool
# ==================================================
# ==================================================
# 📊 OUTLIER DETECTION: df_tests
# ==================================================
# ❌ ID: TST-000045 - 782.06 cSt is too high (max: 500)
# ❌ ID: TST-000092 - -20.0 kg/m3 is too low (min: 0)
# ❌ ID: TST-000111 - 400.0 C is too high (max: 300)
# ❌ ID: TST-000150 - 50000.0 mg/kg is too high (max: 1000)
# ❌ ID: TST-000170 - 749.94 cSt is too high (max: 500)
# ❌ ID: TST-000493 - 2500.0 kg/m3 is too high (max: 1000)
# ❌ ID: TST-000556 - 2500.0 kg/m3 is too high (max: 1000)
# ❌ ID: TST-000750 - 50000.0 mg/kg is too high (max: 1000)
# ❌ ID: TST-000865 - -5.0 mg/kg is too low (min: 0)
# ❌ ID: TST-000866 - 9999.0 mg/kg is too high (max: 1000)
# ❌ ID: TST-000934 - -5.0 mg/kg is too low (min: 0)
# ❌ ID: TST-001007 - -20.0 kg/m3 is too low (min: 0)
# ❌ ID: TST-001016 - 50000.0 mg/kg is too high (max: 1000)
# ❌ ID: TST-001094 - 2500.0 kg/m3 is too high (max: 1000)
# ❌ ID: TST-001383 - 50000.0 mg/kg is too high (max: 1000)
# ❌ ID: TST-001624 - 400.0 C is too high (max: 300)
# ❌ ID: TST-001658 - 50000.0 mg/kg is too high (max: 1000)
# ❌ ID: TST-001681 - 50000.0 mg/kg is too high (max: 1000)
# ❌ ID: TST-001723 - 50000.0 mg/kg is too high (max: 1000)
# ❌ ID: TST-001741 - 50000.0 mg/kg is too high (max: 1000)
# ❌ ID: TST-001755 - -5.0 mg/kg is too low (min: 0)
# ❌ ID: TST-001778 - 931.25 cSt is too high (max: 500)
# ❌ ID: TST-001803 - 400.0 C is too high (max: 300)
# ❌ ID: TST-001820 - 400.0 C is too high (max: 300)
# ❌ ID: TST-001916 - 930.09 cSt is too high (max: 500)
# ❌ ID: TST-001930 - 50000.0 mg/kg is too high (max: 1000)
# ❌ ID: TST-001948 - 9999.0 mg/kg is too high (max: 1000)
# ❌ ID: TST-001979 - 9999.0 mg/kg is too high (max: 1000)
# ❌ ID: TST-002086 - 1500.0 cSt is too high (max: 500)
# ❌ ID: TST-002417 - 909.23 cSt is too high (max: 500)
# ❌ ID: TST-002426 - 2500.0 kg/m3 is too high (max: 1000)
# ❌ ID: TST-002641 - -20.0 kg/m3 is too low (min: 0)
# ❌ ID: TST-002871 - -20.0 kg/m3 is too low (min: 0)
# ❌ ID: TST-002892 - 50000.0 mg/kg is too high (max: 1000)
# ❌ ID: TST-002975 - 840.05 cSt is too high (max: 500)
# ❌ ID: TST-003011 - -3.0 cSt is too low (min: 0)
# ❌ ID: TST-003084 - 50000.0 mg/kg is too high (max: 1000)
# ❌ ID: TST-003242 - 50000.0 mg/kg is too high (max: 1000)
# ❌ ID: TST-003513 - 50000.0 mg/kg is too high (max: 1000)
# ❌ ID: TST-003614 - -20.0 kg/m3 is too low (min: 0)
# ❌ ID: TST-003636 - 50000.0 mg/kg is too high (max: 1000)
# ❌ ID: TST-003637 - -5.0 mg/kg is too low (min: 0)
# ❌ ID: TST-003706 - 400.0 C is too high (max: 300)
# ❌ ID: TST-003748 - 9999.0 mg/kg is too high (max: 1000)
# ❌ ID: TST-003822 - 50000.0 mg/kg is too high (max: 1000)
# ==================================================
