# %%
import pandas as pd
import numpy as np
import DataInspector as di


df_lab_events = pd.read_csv('../data/raw/lab_events.csv', encoding='utf-8')
df_samples = pd.read_csv('../data/raw/samples.csv', encoding='utf-8')
df_tests = pd.read_csv('../data/raw/tests.csv', encoding='utf-8')

# ========================================================================================================================
# Tests method:
# ========================================================================================================================
di.DataInspector.duplicated_in_tests(df_tests, 'df_tests', 'test_id','parameter')
#    def duplicated_in_tests(df: pd.DataFrame, name: str = "Dataset", test_id: str = 'test_id', parameter: str = 'parameter') -> None:


#    def unlogical_combination(df: pd.DataFrame, name: str = "Null value", first_column_name: str = None, second_column_name: str = None):
# Out:
# ==================================================
# 📊 DUPLICATE ANALYSIS
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3862     True
# 3863     True
# 3864     True
# 3865     True
# 3866     True
# Length: 3867, dtype: bool
# ==================================================
