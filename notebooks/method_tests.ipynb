# %%
import pandas as pd
import numpy as np
import DataInspector as di


df_lab_events = pd.read_csv('../data/raw/lab_events.csv', encoding='utf-8')
df_samples = pd.read_csv('../data/raw/samples.csv', encoding='utf-8')
df_tests = pd.read_csv('../data/raw/tests.csv', encoding='utf-8')
df_lab_events = pd.read_csv('../data/raw/lab_events.csv', encoding='utf-8')
# ========================================================================================================================
# Tests method:
# ========================================================================================================================
di.DataInspector.validate_required_events_per_sample(df_lab_events, "df_lab_events","sample_id", "event_type")
# Out:
# ============================================================
# 📊 REQUIRED EVENTS VALIDATION: df_lab_events
# ============================================================
# ✅ Every sample has all required events
# ============================================================
